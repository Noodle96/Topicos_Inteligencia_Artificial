# %% [markdown]
# **<h1>Preprocesamiento</h1>**

# %% [markdown]
# **1.- Filtrar y guardar los índices:**
#
#
# Filtrar los índices si en caso no hayan sido filtrados, caso contrario cargarlos

# %%
import torch
import torchvision
from torchvision import transforms
from PIL import Image, ImageDraw
import cv2
import os
import json

# %%
# Definir la ruta local donde se guardarán los datos y los índices filtrados
root = '/home/russell/git/CountPeople/voc_dataset'  # Cambia esta ruta a la ubicación donde deseas guardar los datos

# Verificar si el dataset ya existe
train_dir = os.path.join(root, 'VOCdevkit', 'VOC2012', 'JPEGImages')
val_dir = os.path.join(root, 'VOCdevkit', 'VOC2012', 'JPEGImages')

print(train_dir)
print(val_dir)
# Out:
# /home/russell/git/CountPeople/voc_dataset/VOCdevkit/VOC2012/JPEGImages
# /home/russell/git/CountPeople/voc_dataset/VOCdevkit/VOC2012/JPEGImages

# %%
# Descargar y preparar el dataset Pascal VOC 2012 si no existe
if not os.path.exists(train_dir):
    dataset_train = torchvision.datasets.VOCDetection(root=root, year='2012', image_set='train', download=True)
    print("no existe train_dir")
else:
    dataset_train = torchvision.datasets.VOCDetection(root=root, year='2012', image_set='train', download=False)
    print("existe train_dir")

if not os.path.exists(val_dir):
    dataset_val = torchvision.datasets.VOCDetection(root=root, year='2012', image_set='val', download=True)
    print("no existe val_dir")
else:
    dataset_val = torchvision.datasets.VOCDetection(root=root, year='2012', image_set='val', download=False)
    print("existe val_dir")

# Ver un ejemplo de datos
img, target = dataset_train[0]
print("Imagen:", img)
print("Anotaciones:", target)
# Out:
# existe train_dir
# existe val_dir
# Imagen: <PIL.Image.Image image mode=RGB size=500x442 at 0x7676105C06A0>
# Anotaciones: {'annotation': {'folder': 'VOC2012', 'filename': '2008_000008.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '442', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'horse', 'pose': 'Left', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '53', 'ymin': '87', 'xmax': '471', 'ymax': '420'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '158', 'ymin': '44', 'xmax': '289', 'ymax': '167'}, 'difficult': '0'}]}}

# %%
print(dataset_train)
print(dataset_val)
# Out:
# Dataset VOCDetection
#     Number of datapoints: 5717
#     Root location: /home/russell/git/CountPeople/voc_dataset
# Dataset VOCDetection
#     Number of datapoints: 5823
#     Root location: /home/russell/git/CountPeople/voc_dataset

# %%
# Filtrar los índices y guardarlos
def filter_indices(dataset, class_name="person"):
    indices = []
    for idx in range(len(dataset)):
        # print(idx)
        img, target = dataset[idx]
        if any(obj['name'] == class_name for obj in target['annotation']['object']):
            indices.append(idx)
    print(f"Number of images containing '{class_name}':", len(indices))
    return indices

# %%
# Verificar y cargar los índices filtrados para entrenamiento
train_indices_path = os.path.join(root, 'filtered_train_indices.json')
if os.path.exists(train_indices_path):
    print("train_indices_path existe")
    with open(train_indices_path, 'r') as f:
        filtered_train_indices = json.load(f)
else:
    print("train_indices_path no existe")
    filtered_train_indices = filter_indices(dataset_train)
    with open(train_indices_path, 'w') as f:
        json.dump(filtered_train_indices, f)

# # Verificar y cargar los índices filtrados para validación
val_indices_path = os.path.join(root, 'filtered_val_indices.json')
if os.path.exists(val_indices_path):
    print("val_indices_path existe")
    with open(val_indices_path, 'r') as f:
        filtered_val_indices = json.load(f)
else:
    print("val_indices_path no existe")
    filtered_val_indices = filter_indices(dataset_val)
    with open(val_indices_path, 'w') as f:
        json.dump(filtered_val_indices, f)
# Out:
# train_indices_path existe
# val_indices_path existe

# %%
print(filtered_train_indices)
print(len(filtered_train_indices))
# Out:
# [0, 3, 6, 8, 19, 24, 26, 28, 29, 30, 31, 32, 37, 39, 42, 43, 45, 48, 49, 50, 51, 52, 54, 55, 56, 58, 59, 60, 61, 63, 65, 66, 67, 69, 70, 72, 74, 75, 76, 77, 79, 82, 83, 84, 85, 90, 91, 92, 93, 94, 95, 100, 101, 102, 103, 104, 106, 107, 108, 110, 111, 112, 113, 114, 115, 116, 119, 122, 124, 128, 130, 131, 132, 133, 134, 135, 136, 138, 139, 141, 142, 143, 144, 146, 148, 149, 150, 153, 154, 156, 157, 158, 159, 160, 162, 163, 166, 167, 168, 171, 174, 176, 178, 179, 180, 181, 182, 183, 185, 188, 189, 190, 191, 193, 195, 197, 198, 199, 200, 202, 204, 205, 206, 207, 208, 209, 210, 213, 214, 215, 216, 217, 219, 220, 222, 224, 229, 230, 231, 232, 233, 234, 235, 236, 238, 239, 240, 241, 243, 244, 245, 246, 247, 248, 250, 251, 252, 253, 256, 257, 258, 260, 262, 263, 264, 265, 267, 268, 269, 271, 274, 277, 278, 283, 284, 285, 286, 287, 288, 289, 291, 293, 294, 295, 296, 297, 299, 300, 302, 304, 306, 307, 308, 309, 310, 311, 312, 313, 316, 317, 319, 320, 321, 322, 323, 324, 325, 327, 328, 330, 332, 333, 335, 336, 337, 338, 339, 340, 343, 344, 346, 347, 348, 349, 351, 352, 353, 357, 358, 359, 360, 361, 362, 363, 365, 366, 367, 368, 369, 370, 371, 374, 376, 377, 378, 380, 383, 384, 385, 387, 388, 389, 390, 392, 394, 396, 398, 400, 401, 404, 405, 406, 407, 410, 411, 412, 413, 415, 419, 420, 421, 422, 423, 425, 428, 429, 431, 432, 433, 435, 436, 437, 438, 440, 444, 445, 446, 447, 449, 450, 453, 454, 456, 457, 459, 460, 461, 462, 463, 464, 465, 468, 469, 471, 472, 473, 475, 476, 477, 481, 483, 484, 485, 486, 487, 488, 489, 490, 491, 494, 495, 496, 497, 498, 499, 500, 502, 505, 507, 512, 514, 517, 522, 523, 524, 525, 526, 527, 530, 534, 538, 539, 540, 542, 543, 544, 545, 547, 550, 552, 554, 555, 556, 557, 561, 564, 565, 566, 567, 568, 569, 571, 572, 573, 574, 575, 576, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 595, 597, 598, 599, 600, 601, 602, 603, 606, 608, 609, 610, 612, 613, 614, 616, 617, 619, 620, 621, 624, 625, 626, 627, 633, 634, 636, 637, 638, 639, 640, 642, 643, 644, 645, 648, 649, 651, 652, 654, 655, 656, 657, 658, 660, 661, 663, 664, 665, 666, 667, 669, 670, 671, 672, 675, 676, 680, 681, 682, 683, 686, 687, 688, 690, 692, 697, 698, 699, 701, 702, 703, 704, 705, 708, 709, 711, 713, 718, 719, 721, 723, 724, 725, 728, 729, 730, 732, 734, 735, 736, 737, 738, 739, 740, 741, 743, 744, 745, 749, 750, 753, 754, 755, 757, 758, 759, 761, 762, 766, 767, 772, 773, 774, 775, 776, 780, 781, 782, 783, 786, 787, 788, 789, 795, 798, 800, 801, 802, 804, 805, 807, 811, 812, 813, 814, 817, 818, 819, 822, 824, 829, 830, 831, 832, 834, 835, 836, 837, 838, 839, 841, 844, 845, 849, 852, 853, 854, 855, 857, 858, 859, 863, 867, 868, 869, 870, 871, 872, 874, 876, 879, 880, 881, 885, 887, 888, 889, 890, 891, 892, 895, 896, 898, 899, 900, 903, 904, 907, 908, 911, 912, 913, 915, 916, 917, 918, 919, 920, 921, 923, 924, 925, 927, 930, 931, 932, 933, 937, 938, 939, 941, 942, 948, 953, 954, 956, 957, 958, 959, 961, 963, 965, 967, 968, 972, 975, 976, 980, 981, 982, 985, 986, 987, 988, 989, 990, 993, 997, 998, 1001, 1002, 1006, 1007, 1011, 1013, 1015, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1025, 1026, 1027, 1029, 1031, 1032, 1033, 1038, 1041, 1042, 1043, 1044, 1048, 1052, 1054, 1055, 1056, 1058, 1059, 1060, 1061, 1062, 1063, 1065, 1066, 1067, 1071, 1072, 1074, 1082, 1083, 1085, 1086, 1089, 1093, 1094, 1095, 1098, 1100, 1103, 1104, 1105, 1107, 1109, 1110, 1111, 1116, 1120, 1122, 1125, 1126, 1130, 1132, 1135, 1137, 1138, 1141, 1144, 1145, 1147, 1148, 1150, 1152, 1153, 1158, 1161, 1162, 1165, 1166, 1168, 1172, 1175, 1178, 1180, 1183, 1184, 1186, 1188, 1189, 1190, 1192, 1195, 1201, 1202, 1203, 1208, 1212, 1213, 1216, 1217, 1218, 1219, 1220, 1224, 1226, 1229, 1232, 1234, 1241, 1245, 1246, 1248, 1252, 1254, 1259, 1263, 1268, 1275, 1276, 1280, 1281, 1282, 1284, 1285, 1294, 1296, 1298, 1302, 1305, 1308, 1309, 1313, 1314, 1317, 1319, 1325, 1327, 1328, 1329, 1332, 1337, 1338, 1346, 1348, 1351, 1359, 1361, 1365, 1366, 1370, 1371, 1379, 1384, 1386, 1388, 1392, ...
# 2142

# %%
print(filtered_val_indices)
print(len(filtered_val_indices))
# Out:
# [1, 6, 8, 9, 13, 14, 17, 20, 26, 28, 32, 37, 47, 48, 49, 50, 51, 52, 54, 55, 56, 57, 59, 61, 64, 66, 67, 68, 69, 70, 73, 74, 75, 76, 80, 81, 82, 84, 86, 88, 89, 91, 93, 94, 95, 97, 99, 100, 101, 102, 103, 105, 107, 108, 109, 110, 115, 117, 118, 119, 120, 121, 122, 123, 126, 127, 128, 129, 130, 133, 135, 136, 137, 138, 139, 140, 142, 143, 144, 145, 148, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 165, 166, 167, 168, 170, 171, 172, 173, 174, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 190, 191, 192, 194, 197, 198, 199, 202, 203, 205, 206, 207, 208, 209, 216, 217, 219, 220, 222, 224, 225, 227, 228, 230, 232, 233, 234, 235, 237, 239, 243, 244, 245, 246, 247, 248, 249, 250, 252, 253, 254, 255, 256, 257, 258, 261, 262, 263, 265, 266, 267, 269, 270, 271, 274, 275, 276, 277, 278, 279, 281, 282, 284, 285, 288, 289, 290, 292, 295, 296, 298, 299, 300, 302, 304, 305, 309, 310, 311, 312, 313, 315, 316, 317, 318, 319, 323, 324, 325, 326, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 339, 340, 341, 342, 344, 345, 346, 347, 348, 350, 352, 353, 354, 355, 356, 357, 361, 363, 365, 368, 371, 373, 375, 376, 378, 379, 380, 381, 382, 383, 386, 387, 389, 390, 391, 392, 393, 394, 399, 400, 401, 402, 403, 404, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 422, 423, 424, 426, 427, 428, 429, 430, 432, 433, 434, 436, 437, 440, 441, 442, 443, 446, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 461, 463, 464, 467, 468, 469, 470, 472, 473, 475, 477, 479, 481, 482, 485, 486, 487, 488, 491, 493, 494, 495, 496, 498, 499, 500, 501, 502, 503, 504, 505, 508, 509, 510, 512, 514, 517, 520, 521, 522, 523, 525, 526, 527, 528, 529, 531, 532, 533, 534, 535, 536, 539, 540, 541, 542, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 558, 559, 560, 561, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 576, 581, 582, 584, 588, 589, 590, 593, 595, 599, 600, 601, 602, 603, 604, 605, 606, 607, 609, 612, 614, 615, 618, 621, 622, 625, 626, 627, 628, 629, 632, 634, 636, 637, 638, 641, 644, 645, 647, 648, 650, 651, 652, 653, 657, 658, 661, 662, 663, 665, 666, 667, 668, 669, 670, 671, 672, 674, 676, 677, 678, 679, 680, 681, 684, 685, 686, 687, 688, 689, 690, 691, 693, 694, 699, 701, 703, 705, 706, 707, 708, 709, 711, 712, 713, 714, 715, 716, 717, 719, 721, 723, 724, 725, 726, 727, 729, 730, 732, 733, 735, 736, 737, 738, 739, 740, 743, 746, 747, 748, 751, 752, 754, 758, 759, 760, 761, 762, 764, 765, 767, 768, 769, 770, 773, 774, 775, 776, 777, 778, 781, 782, 785, 786, 788, 792, 793, 794, 795, 797, 798, 800, 801, 802, 803, 807, 808, 810, 813, 814, 815, 816, 822, 823, 826, 827, 828, 829, 831, 834, 836, 838, 839, 842, 844, 845, 846, 847, 848, 850, 852, 853, 854, 856, 858, 859, 860, 862, 864, 865, 866, 867, 870, 872, 873, 874, 875, 876, 879, 880, 881, 883, 886, 887, 888, 889, 891, 892, 894, 896, 897, 898, 900, 901, 903, 904, 907, 908, 909, 910, 911, 913, 915, 921, 922, 923, 924, 926, 927, 928, 930, 934, 936, 937, 938, 939, 940, 942, 944, 946, 952, 953, 954, 955, 957, 959, 960, 962, 963, 964, 966, 968, 970, 972, 975, 976, 978, 979, 980, 982, 983, 985, 988, 989, 992, 993, 994, 996, 998, 999, 1000, 1001, 1003, 1004, 1010, 1011, 1014, 1016, 1017, 1019, 1021, 1023, 1024, 1025, 1026, 1028, 1030, 1033, 1035, 1036, 1040, 1041, 1042, 1045, 1046, 1047, 1049, 1050, 1052, 1054, 1056, 1057, 1058, 1059, 1061, 1063, 1066, 1068, 1069, 1071, 1072, 1073, 1074, 1080, 1081, 1084, 1085, 1086, 1088, 1091, 1092, 1094, 1095, 1096, 1099, 1100, 1101, 1104, 1111, 1114, 1117, 1118, 1119, 1121, 1125, 1127, 1130, 1133, 1134, 1137, 1142, 1143, 1146, 1148, 1150, 1153, 1154, 1156, 1158, 1159, 1160, 1162, 1163, 1164, 1168, 1170, 1171, 1173, 1177, 1178, 1179, 1181, 1182, 1183, 1186, 1187, 1188, 1189, 1193, 1195, 1199, 1204, 1208, 1209, 1211, 1212, 1215, 1218, 1224, 1227, 1228, 1229, 1234, 1237, 1239, 1241, 1247, 1248, 1249, 1255, 1256, 1258, 1261, 1262, 1264, 1265, 1267, 1268, 1271, 1278, 1280, 1281, 1284, 1286, 1289, 1292, 1294, 129 ...
# 2232

# %% [markdown]
# **2.- Transformaciones y Preparación del Dataset**
#
# Transformacion y implementacion del nuevo dataset con los indices filtrados

# %%
# Transformaciones y Preparación del Dataset
from torchvision.transforms import functional as F

def transform(img, target):
    img = F.to_tensor(img)
    return img, target

class FilteredVOCDataset(torch.utils.data.Dataset):
    def __init__(self, dataset, indices, transforms=None):
        self.dataset = dataset
        self.indices = indices
        self.transforms = transforms

    def __getitem__(self, idx):
        actual_idx = self.indices[idx]
        img, target = self.dataset[actual_idx]

        boxes = []
        labels = []
        for obj in target['annotation']['object']:
            if obj['name'] != "person":
                continue
            bbox = obj['bndbox']
            xmin = int(bbox['xmin'])
            ymin = int(bbox['ymin'])
            xmax = int(bbox['xmax'])
            ymax = int(bbox['ymax'])
            boxes.append([xmin, ymin, xmax, ymax])
            labels.append(1)  # 1 para persona

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        image_id = torch.tensor([idx])

        if len(boxes) == 0:
            area = torch.tensor([0], dtype=torch.float32)  # If empty, set area to 0
        else:
            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        iscrowd = torch.zeros((len(boxes),), dtype=torch.int64)

        target = {}
        target['boxes'] = boxes
        target['labels'] = labels
        target['image_id'] = image_id
        target['area'] = area
        target['iscrowd'] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.indices)

# %%
# Crear los conjuntos de datos filtrados
voc_dataset_train = FilteredVOCDataset(dataset_train, filtered_train_indices, transforms=transform)
voc_dataset_val = FilteredVOCDataset(dataset_val, filtered_val_indices, transforms=transform)

# %%
print(len(voc_dataset_train))
print(len(voc_dataset_val))
# Out:
# 2142
# 2232

# %%
# Dividir los datos en lotes
data_loader_train = torch.utils.data.DataLoader(voc_dataset_train, batch_size=2, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
data_loader_val = torch.utils.data.DataLoader(voc_dataset_val, batch_size=2, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

# Ver un ejemplo de datos
img, target = voc_dataset_train[0]
print(len(data_loader_train))
print(len(data_loader_val))
# Out:
# 1071
# 1116

# %% [markdown]
# > Estimar el número de iteraciones por época

# %%
# Estimar el numero de iteraciones por epoca
batch_size = 2
num_train_samples = len(voc_dataset_train)
num_iterations_per_epoch = num_train_samples // batch_size
if num_train_samples % batch_size != 0:
    num_iterations_per_epoch += 1  # Considerar la última iteración si hay un lote incompleto
print(f'Número de iteraciones por época: {num_iterations_per_epoch}')
# Out:
# Número de iteraciones por época: 1071

# %% [markdown]
# **3.- Definición del modelo**

# %%
# Definición del Modelo
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
in_features = model.roi_heads.box_predictor.cls_score.in_features
num_classes = 2  # 1 clase (persona) + fondo
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)
print("device: ", device)
# Out:
# /home/russell/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/russell/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# device:  cuda

# %% [markdown]
# **4.- Entrenamiento**

# %%
# Entrenamiento
import time

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
num_epochs = 1

for epoch in range(num_epochs):
    start_epoch_time = time.time()


    model.train()
    i = 0
    start_train_time = time.time()
    for images, targets in data_loader_train:
        batch_start_time = time.time()
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        if any(t['boxes'].numel() == 0 for t in targets):
            continue # Skip this batch if any target boxes tensor is empty
        loss_dict = model(images, targets)
        # print(type(loss_dict))
        # print("loss_dict ", loss_dict)
        # print("loss_dict.values(): ", loss_dict.values())
        losses = sum(loss for loss in loss_dict.values())
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        batch_end_time = time.time()
        if i % 10 == 0:
            print(f'Epoch {epoch}, Iteration {i}, Loss: {losses.item()}, Batch Time: {batch_end_time - batch_start_time:.2f}s')
        i += 1
    end_train_time = time.time()
    print(f'Epoch {epoch}, Training Time: {end_train_time - start_train_time:.2f}s')
    lr_scheduler.step()

    # Evaluar el modelo
    # model.eval()
    # validation_loss = 0
    # start_val_time = time.time()
    # i = 0
    # with torch.no_grad():
    #     for images, targets in data_loader_val:
    #         batch_start_time = time.time()
    #         images = list(image.to(device) for image in images)
    #         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

    #         # Check if any target boxes tensor is empty
    #         if any(t['boxes'].numel() == 0 for t in targets):
    #             continue # Skip this batch if any target boxes tensor is empty

    #         # with torch.no_grad():
    #             losses_dict = model(images, targets)


    #         # loss_dict = model(images, targets)
    #         # print("type: ", type(loss_dict))
    #         # print("loss_dict: ",loss_dict)
    #         # if isinstance(loss_dict, dict):  # Asegúrate de que loss_dict sea un diccionario
    #         #     print(type(loss_dict))
    #         losses = sum(loss for loss in loss_dict.values())
    #         validation_loss += losses.item()

    #         batch_end_time = time.time()
    #         if(i % 10 == 0) :
    #             print(f'Epoch {epoch}, Iteration {i}, Validation Batch Time: {batch_end_time - batch_start_time:.2f}s')
    #             print(f'Epoch {epoch}, Iteration {i}, Loss: {losses.item()}, Batch Time: {batch_end_time - batch_start_time:.2f}s')

    #         i += 1
    # end_val_time = time.time()
    # print(f'Validation Time: {end_val_time - start_val_time:.2f}s')
    end_epoch_time = time.time()
    print(f'Epoch {epoch} Total Time: {end_epoch_time - start_epoch_time:.2f}s')
    # print(f'Epoch {epoch}, Validation Loss: {validation_loss / len(data_loader_val)}')
# Out:
# Epoch 0, Iteration 0, Loss: 0.9061770439147949, Batch Time: 1.63s
# Epoch 0, Iteration 10, Loss: 0.5042456984519958, Batch Time: 0.72s
# Epoch 0, Iteration 20, Loss: 0.2936858534812927, Batch Time: 0.77s
# Epoch 0, Iteration 30, Loss: 0.17464639246463776, Batch Time: 0.62s
# Epoch 0, Iteration 40, Loss: 0.3255823254585266, Batch Time: 0.69s
# Epoch 0, Iteration 50, Loss: 0.20245684683322906, Batch Time: 0.83s
# Epoch 0, Iteration 60, Loss: 0.07733730971813202, Batch Time: 0.72s
# Epoch 0, Iteration 70, Loss: 0.5115142464637756, Batch Time: 0.81s
# Epoch 0, Iteration 80, Loss: 0.1605580747127533, Batch Time: 0.71s
# Epoch 0, Iteration 90, Loss: 0.2584396302700043, Batch Time: 0.64s
# Epoch 0, Iteration 100, Loss: 0.13179710507392883, Batch Time: 0.64s
# Epoch 0, Iteration 110, Loss: 0.12591752409934998, Batch Time: 0.98s
# Epoch 0, Iteration 120, Loss: 0.13565945625305176, Batch Time: 0.72s
# Epoch 0, Iteration 130, Loss: 0.3736007511615753, Batch Time: 0.67s
# Epoch 0, Iteration 140, Loss: 0.10946100950241089, Batch Time: 0.70s
# Epoch 0, Iteration 150, Loss: 0.45422500371932983, Batch Time: 0.63s
# Epoch 0, Iteration 160, Loss: 0.46331891417503357, Batch Time: 0.80s
# Epoch 0, Iteration 170, Loss: 0.5854208469390869, Batch Time: 0.83s
# Epoch 0, Iteration 180, Loss: 0.11331164091825485, Batch Time: 0.64s
# Epoch 0, Iteration 190, Loss: 0.3312724530696869, Batch Time: 0.76s
# Epoch 0, Iteration 200, Loss: 0.5001642107963562, Batch Time: 0.76s
# Epoch 0, Iteration 210, Loss: 0.17738094925880432, Batch Time: 0.60s
# Epoch 0, Iteration 220, Loss: 0.14528049528598785, Batch Time: 0.76s
# Epoch 0, Iteration 230, Loss: 0.15082286298274994, Batch Time: 0.76s
# Epoch 0, Iteration 240, Loss: 0.21710193157196045, Batch Time: 0.64s
# Epoch 0, Iteration 250, Loss: 0.46471184492111206, Batch Time: 0.65s
# Epoch 0, Iteration 260, Loss: 0.33147358894348145, Batch Time: 0.63s
# Epoch 0, Iteration 270, Loss: 0.3475227952003479, Batch Time: 0.78s
# Epoch 0, Iteration 280, Loss: 0.13477551937103271, Batch Time: 0.79s
# Epoch 0, Iteration 290, Loss: 0.37589120864868164, Batch Time: 0.63s
# Epoch 0, Iteration 300, Loss: 0.15388567745685577, Batch Time: 0.75s
# Epoch 0, Iteration 310, Loss: 0.09767461568117142, Batch Time: 0.80s
# Epoch 0, Iteration 320, Loss: 0.14096437394618988, Batch Time: 0.72s
# Epoch 0, Iteration 330, Loss: 0.1993735134601593, Batch Time: 0.70s
# Epoch 0, Iteration 340, Loss: 0.13591890037059784, Batch Time: 0.76s
# Epoch 0, Iteration 350, Loss: 0.16854222118854523, Batch Time: 0.74s
# Epoch 0, Iteration 360, Loss: 0.7626408338546753, Batch Time: 0.73s
# Epoch 0, Iteration 370, Loss: 0.35343778133392334, Batch Time: 0.71s
# Epoch 0, Iteration 380, Loss: 0.10641362518072128, Batch Time: 0.72s
# Epoch 0, Iteration 390, Loss: 0.36883556842803955, Batch Time: 0.82s
# Epoch 0, Iteration 400, Loss: 0.15781113505363464, Batch Time: 0.79s
# Epoch 0, Iteration 410, Loss: 0.21272432804107666, Batch Time: 0.80s
# Epoch 0, Iteration 420, Loss: 0.4141002595424652, Batch Time: 0.81s
# Epoch 0, Iteration 430, Loss: 0.12391617149114609, Batch Time: 0.68s
# Epoch 0, Iteration 440, Loss: 0.1672065258026123, Batch Time: 0.73s
# Epoch 0, Iteration 450, Loss: 0.19187279045581818, Batch Time: 0.69s
# Epoch 0, Iteration 460, Loss: 0.14713095128536224, Batch Time: 0.84s
# Epoch 0, Iteration 470, Loss: 0.29451504349708557, Batch Time: 0.74s
# Epoch 0, Iteration 480, Loss: 0.27798160910606384, Batch Time: 0.77s
# Epoch 0, Iteration 490, Loss: 0.1474762111902237, Batch Time: 0.74s
# Epoch 0, Iteration 500, Loss: 0.33081403374671936, Batch Time: 0.68s
# Epoch 0, Iteration 510, Loss: 0.1591065227985382, Batch Time: 0.73s
# Epoch 0, Iteration 520, Loss: 0.20134517550468445, Batch Time: 1.01s
# Epoch 0, Iteration 530, Loss: 0.19062058627605438, Batch Time: 0.70s
# Epoch 0, Iteration 540, Loss: 0.24398332834243774, Batch Time: 0.88s
# Epoch 0, Iteration 550, Loss: 0.06841329485177994, Batch Time: 0.67s
# Epoch 0, Iteration 560, Loss: 0.17506149411201477, Batch Time: 0.79s
# Epoch 0, Iteration 570, Loss: 0.2478766143321991, Batch Time: 0.88s
# Epoch 0, Iteration 580, Loss: 0.23672735691070557, Batch Time: 0.74s
# Epoch 0, Iteration 590, Loss: 0.34832504391670227, Batch Time: 0.77s
# Epoch 0, Iteration 600, Loss: 0.27776387333869934, Batch Time: 0.82s
# Epoch 0, Iteration 610, Loss: 0.26190975308418274, Batch Time: 0.72s
# Epoch 0, Iteration 620, Loss: 0.21066458523273468, Batch Time: 0.74s
# Epoch 0, Iteration 630, Loss: 0.37890157103538513, Batch Time: 0.75s
# Epoch 0, Iteration 640, Loss: 0.14275796711444855, Batch Time: 0.93s
# Epoch 0, Iteration 650, Loss: 0.43484288454055786, Batch Time: 0.98s
# Epoch 0, Iteration 660, Loss: 0.5199467539787292, Batch Time: 0.70s
# Epoch 0, Iteration 670, Loss: 0.14456945657730103, Batch Time: 0.70s
# Epoch 0, Iteration 680, Loss: 0.11484481394290924, Batch Time: 0.79s
# Epoch 0, Iteration 690, Loss: 0.30073004961013794, Batch Time: 0.90s
# Epoch 0, Iteration 700, Loss: 0.09034260362386703, Batch Time: 0.71s
# Epoch 0, Iteration 710, Loss: 0.6417372226715088, Batch Time: 0.74s
# Epoch 0, Iteration 720, Loss: 0.4138771891593933, Batch Time: 0.82s
# Epoch 0, Iteration 730, Loss: 0.22810594737529755, Batch Time: 0.80s
# Epoch 0, Iteration 740, Loss: 0.25467967987060547, Batch Time: 0.94s
# Epoch 0, Iteration 750, Loss: 0.3373396098613739, Batch Time: 0.72s
# Epoch 0, Iteration 760, Loss: 0.5825082659721375, Batch Time: 0.84s
# Epoch 0, Iteration 770, Loss: 0.34224021434783936, Batch Time: 0.70s
# Epoch 0, Iteration 780, Loss: 0.053041182458400726, Batch Time: 0.82s
# Epoch 0, Iteration 790, Loss: 0.36483126878738403, Batch Time: 0.82s
# Epoch 0, Iteration 800, Loss: 0.4135383069515228, Batch Time: 0.70s
# Epoch 0, Iteration 810, Loss: 0.055145613849163055, Batch Time: 0.83s
# Epoch 0, Iteration 820, Loss: 0.2383606880903244, Batch Time: 0.70s
# Epoch 0, Iteration 830, Loss: 0.19478246569633484, Batch Time: 0.76s
# Epoch 0, Iteration 840, Loss: 0.36706680059432983, Batch Time: 0.78s
# Epoch 0, Iteration 850, Loss: 0.26105111837387085, Batch Time: 0.74s
# Epoch 0, Iteration 860, Loss: 0.11394970118999481, Batch Time: 0.67s
# Epoch 0, Iteration 870, Loss: 0.05446890741586685, Batch Time: 0.97s
# Epoch 0, Iteration 880, Loss: 0.2796066403388977, Batch Time: 0.82s
# Epoch 0, Iteration 890, Loss: 0.10196267068386078, Batch Time: 0.70s
# Epoch 0, Iteration 900, Loss: 0.14724527299404144, Batch Time: 0.80s
# Epoch 0, Iteration 910, Loss: 0.3028092682361603, Batch Time: 0.86s
# Epoch 0, Iteration 920, Loss: 0.1403847336769104, Batch Time: 0.88s
# Epoch 0, Iteration 930, Loss: 0.10767091065645218, Batch Time: 0.91s
# Epoch 0, Iteration 940, Loss: 0.090219646692276, Batch Time: 0.83s
# Epoch 0, Iteration 950, Loss: 0.15998344123363495, Batch Time: 0.70s
# Epoch 0, Iteration 960, Loss: 0.509006917476654, Batch Time: 0.73s
# Epoch 0, Iteration 970, Loss: 0.1614735722541809, Batch Time: 0.82s
# Epoch 0, Iteration 980, Loss: 0.3336939513683319, Batch Time: 0.76s
# Epoch 0, Iteration 990, Loss: 0.17100149393081665, Batch Time: 0.83s
# Epoch 0, Iteration 1000, Loss: 0.23799863457679749, Batch Time: 0.72s
# Epoch 0, Iteration 1010, Loss: 0.12386208772659302, Batch Time: 0.84s
# Epoch 0, Iteration 1020, Loss: 0.13311997056007385, Batch Time: 0.71s
# Epoch 0, Iteration 1030, Loss: 0.27972230315208435, Batch Time: 0.71s
# Epoch 0, Iteration 1040, Loss: 0.14659781754016876, Batch Time: 0.80s
# Epoch 0, Iteration 1050, Loss: 0.32230377197265625, Batch Time: 0.70s
# Epoch 0, Iteration 1060, Loss: 0.34565600752830505, Batch Time: 0.95s
# Epoch 0, Iteration 1070, Loss: 0.21569129824638367, Batch Time: 0.82s
# Epoch 0, Training Time: 822.62s
# Epoch 0 Total Time: 822.62s

# %% [markdown]
# **5.- Guardamos el modelo entrenado**

# %%
# Obtener el directorio de trabajo actual
current_dir = os.getcwd()
print("Current directory:", current_dir)

# Guardar el modelo
torch.save(model.state_dict(), os.path.join(current_dir, 'fasterrcnn_person_detector.pth'))
# Out:
# Current directory: /home/russell/git/CountPeople

# %%
a = 89.7
b = 9
print(type(a))
print(type(b))
# Out:
# <class 'float'>
# <class 'int'>
