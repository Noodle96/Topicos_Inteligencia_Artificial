# %% [markdown]
# ## **Función Sigmoidea**

# %% [markdown]
# <div style="display: flex; flex-direction: row;justify-content: space-between;">
#     <div></div>
#     <img src="https://github.com/Noodle96/Topicos_Inteligencia_Artificial/blob/main/assets/img/sigmoideaFunction.jpeg?raw=true" width="40%">
#     <div></div>
# </div>

# %%
import plotly.graph_objects as go
import numpy as np

# Define the range of x-axis values
x = np.linspace(-2, 2, 400)  # 400 points for smooth curves

# Calculate sine and cosine values
#y_sin = np.sin(x)
#y_cos = np.cos(x)
y_e_pos = np.exp(x)
y_e_neg = np.exp(-x)

# Create the plot
fig = go.Figure()

# Plot the sine function (red line)
# fig.add_trace(go.Scatter(x=x, y=y_sin, mode='lines', name='Sine', line=dict(color='red')))

fig.add_trace(go.Scatter(x=x, y=y_e_pos, mode='lines', name='Exponencial +', line=dict(color='red')))
fig.add_trace(go.Scatter(x=x, y=y_e_neg, mode='lines', name='Exponencial -', line=dict(color='blue')))


# Plot the cosine function (blue line)
#fig.add_trace(go.Scatter(x=x, y=y_cos, mode='lines', name='Cosine', line=dict(color='blue')))

# Add labels and title
fig.update_layout(
    title='Sigmoidea Function',
    xaxis_title='X',
    yaxis_title='Y'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="450d5380-3794-40a3-85b7-b2d899fb76f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("450d5380-3794-40a3-85b7-b2d899fb76f3")) {                    Plotly.newPlot(                        "450d5380-3794-40a3-85b7-b2d899fb76f3",                        [{"line":{"color":"red"},"mode":"lines","name":"Exponencial +","x":[-2.0,-1.9899749373433584,-1.9799498746867168,-1.9699248120300752,-1.9598997493734336,-1.949874686716792,-1.9398496240601504,-1.9298245614035088,-1.9197994987468672,-1.9097744360902256,-1.899749373433584,-1.8897243107769424,-1.8796992481203008,-1.8696741854636592,-1.8596491228070176,-1.849624060150376,-1.8395989974937343,-1.8295739348370927,-1.8195488721804511,-1.8095238095238095,-1.799498746867168,-1.7894736842105263,-1.7794486215538847,-1.7694235588972431,-1.7593984962406015,-1.74937343358396,-1.7393483709273183,-1.7293233082706767,-1.719298245614035,-1.7092731829573935,-1.699248120300752,-1.6892230576441103,-1.6791979949874687,-1.669172932330827,-1.6591478696741855,-1.6491228070175439,-1.6390977443609023,-1.6290726817042607,-1.619047619047619,-1.6090225563909775,-1.5989974937343359,-1.5889724310776943,-1.5789473684210527,-1.568922305764411,-1.5588972431077694,-1.5488721804511278,-1.5388471177944862,-1.5288220551378446,-1.518796992481203,-1.5087719298245614,-1.4987468671679198,-1.4887218045112782,-1.4786967418546366,-1.468671679197995,-1.4586466165413534,-1.4486215538847118,-1.4385964912280702,-1.4285714285714286,-1.418546365914787,-1.4085213032581454,-1.3984962406015038,-1.3884711779448622,-1.3784461152882206,-1.368421052631579,-1.3583959899749374,-1.3483709273182958,-1.3383458646616542,-1.3283208020050126,-1.318295739348371,-1.3082706766917294,-1.2982456140350878,-1.2882205513784462,-1.2781954887218046,-1.268170426065163,-1.2581453634085213,-1.2481203007518797,-1.2380952380952381,-1.2280701754385965,-1.218045112781955,-1.2080200501253133,-1.1979949874686717,-1.1879699248120301,-1.1779448621553885,-1.167919799498747,-1.1578947368421053,-1.1478696741854637,-1.137844611528822,-1.1278195488721805,-1.117794486215539,-1.1077694235588973,-1.0977443609022557,-1.087719298245614,-1.0776942355889725,-1.0676691729323309,-1.0576441102756893,-1.0476190476190477,-1.037593984962406,-1.0275689223057645,-1.0175438596491229,-1.0075187969924813,-0.9974937343358397,-0.987468671679198,-0.9774436090225564,-0.9674185463659148,-0.9573934837092732,-0.9473684210526316,-0.93734335839599,-0.9273182957393484,-0.9172932330827068,-0.9072681704260652,-0.8972431077694236,-0.887218045112782,-0.8771929824561404,-0.8671679197994988,-0.8571428571428572,-0.8471177944862156,-0.837092731829574,-0.8270676691729324,-0.8170426065162908,-0.8070175438596492,-0.7969924812030076,-0.786967418546366,-0.7769423558897244,-0.7669172932330828,-0.7568922305764412,-0.7468671679197996,-0.736842105263158,-0.7268170426065164,-0.7167919799498748,-0.7067669172932332,-0.6967418546365916,-0.68671679197995,-0.6766917293233083,-0.6666666666666667,-0.6566416040100251,-0.6466165413533835,-0.6365914786967419,-0.6265664160401003,-0.6165413533834587,-0.6065162907268171,-0.5964912280701755,-0.5864661654135339,-0.5764411027568923,-0.5664160401002507,-0.5563909774436091,-0.5463659147869675,-0.5363408521303259,-0.5263157894736843,-0.5162907268170427,-0.5062656641604011,-0.4962406015037595,-0.4862155388471179,-0.4761904761904763,-0.46616541353383467,-0.45614035087719307,-0.44611528822055146,-0.43609022556390986,-0.42606516290726826,-0.41604010025062665,-0.40601503759398505,-0.39598997493734345,-0.38596491228070184,-0.37593984962406024,-0.36591478696741864,-0.35588972431077703,-0.34586466165413543,-0.3358395989974938,-0.3258145363408522,-0.3157894736842106,-0.305764411027569,-0.2 ...

# %% [markdown]
# De la imagen anterior hay que recalcar que la función:
# \begin{align*}
#     f(x) = e^x
# \end{align*}
# tiene el siguiente comportamiento:
# \begin{align*}
#     \lim_{x\to\infty} f(x) &= \infty \\
#     \lim_{x\to-\infty} f(x) &= 0
# \end{align*}
#
# Ademas, que la función:
# \begin{align*}
#     g(x) = e^{-x}
# \end{align*}
# tiene el siguiente comportamiento:
# \begin{align*}
#     \lim_{x\to\infty} g(x)&= 0 \\
#     \lim_{x\to-\infty} g(x)&= \infty
# \end{align*}

# %%
import plotly.graph_objects as go
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Define the range of x-axis values
x = np.linspace(-10, 10, 400)  # 400 points for smooth curves

# Calculate sine and cosine values
#y_sin = np.sin(x)
#y_cos = np.cos(x)
y_sigmoidea = sigmoid(x)

# Create the plot
fig = go.Figure()

# Plot the sine function (red line)
# fig.add_trace(go.Scatter(x=x, y=y_sin, mode='lines', name='Sine', line=dict(color='red')))

fig.add_trace(go.Scatter(x=x, y=y_sigmoidea, mode='lines', name='Singmoidea', line=dict(color='red')))

# Plot the cosine function (blue line)
#fig.add_trace(go.Scatter(x=x, y=y_cos, mode='lines', name='Cosine', line=dict(color='blue')))

# Add labels and title
fig.update_layout(
    title='Sigmoidea Function',
    xaxis_title='X',
    yaxis_title='Y'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="45873ee6-362b-4d80-a000-4c6b5eea71eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45873ee6-362b-4d80-a000-4c6b5eea71eb")) {                    Plotly.newPlot(                        "45873ee6-362b-4d80-a000-4c6b5eea71eb",                        [{"line":{"color":"red"},"mode":"lines","name":"Singmoidea","x":[-10.0,-9.949874686716791,-9.899749373433584,-9.849624060150376,-9.799498746867169,-9.74937343358396,-9.699248120300751,-9.649122807017545,-9.598997493734336,-9.548872180451127,-9.49874686716792,-9.448621553884712,-9.398496240601503,-9.348370927318296,-9.298245614035087,-9.24812030075188,-9.197994987468672,-9.147869674185463,-9.097744360902256,-9.047619047619047,-8.99749373433584,-8.947368421052632,-8.897243107769423,-8.847117794486216,-8.796992481203008,-8.746867167919799,-8.696741854636592,-8.646616541353383,-8.596491228070175,-8.546365914786968,-8.496240601503759,-8.446115288220552,-8.395989974937343,-8.345864661654135,-8.295739348370928,-8.24561403508772,-8.195488721804512,-8.145363408521304,-8.095238095238095,-8.045112781954888,-7.994987468671679,-7.9448621553884715,-7.894736842105264,-7.844611528822055,-7.794486215538847,-7.7443609022556394,-7.694235588972431,-7.644110275689223,-7.593984962406015,-7.543859649122807,-7.4937343358396,-7.443609022556391,-7.393483709273183,-7.343358395989975,-7.293233082706767,-7.243107769423559,-7.192982456140351,-7.142857142857143,-7.092731829573935,-7.042606516290727,-6.992481203007519,-6.942355889724311,-6.8922305764411025,-6.842105263157895,-6.791979949874687,-6.741854636591479,-6.691729323308271,-6.641604010025063,-6.591478696741855,-6.541353383458647,-6.491228070175438,-6.4411027568922306,-6.390977443609023,-6.340852130325815,-6.290726817042607,-6.2406015037593985,-6.190476190476191,-6.140350877192983,-6.090225563909774,-6.040100250626566,-5.989974937343359,-5.939849624060151,-5.889724310776943,-5.839598997493734,-5.7894736842105265,-5.739348370927319,-5.68922305764411,-5.639097744360902,-5.5889724310776945,-5.538847117794487,-5.488721804511279,-5.43859649122807,-5.388471177944862,-5.338345864661655,-5.288220551378446,-5.238095238095238,-5.18796992481203,-5.1378446115288225,-5.087719298245615,-5.037593984962406,-4.987468671679198,-4.9373433583959905,-4.887218045112782,-4.837092731829574,-4.786967418546366,-4.736842105263158,-4.686716791979951,-4.636591478696742,-4.586466165413534,-4.536340852130326,-4.486215538847118,-4.43609022556391,-4.385964912280702,-4.335839598997494,-4.2857142857142865,-4.235588972431078,-4.18546365914787,-4.135338345864662,-4.0852130325814535,-4.035087719298246,-3.984962406015038,-3.93483709273183,-3.8847117794486223,-3.8345864661654137,-3.784461152882206,-3.734335839598998,-3.6842105263157894,-3.6340852130325816,-3.583959899749374,-3.533834586466166,-3.483709273182958,-3.4335839598997495,-3.3834586466165417,-3.333333333333334,-3.2832080200501252,-3.2330827067669174,-3.1829573934837097,-3.132832080200502,-3.082706766917294,-3.0325814536340854,-2.9824561403508776,-2.93233082706767,-2.882205513784461,-2.8320802005012533,-2.7819548872180455,-2.7318295739348377,-2.68170426065163,-2.6315789473684212,-2.5814536340852134,-2.5313283208020056,-2.481203007518797,-2.431077694235589,-2.3809523809523814,-2.3308270676691736,-2.280701754385966,-2.230576441102757,-2.1804511278195493,-2.1303258145363415,-2.080200501253133,-2.030075187969925,-1.9799498746867172,-1.9298245614035086,-1.8796992481203016,-1.829573934837093,-1.779448621553886,-1.7293233082706774,-1.6791979949874687,-1.6290726817042618,-1.578947368421053,-1.5288220551378444,-1.4786967418546375,-1.4285714285714288,-1.3784461152882201,-1.3283208020050132,-1.2781954887218046,-1.2280701754385976,-1.17794486 ...

# %% [markdown]
# De la funcion sigmoidea:
# \begin{align*}
#     h(x) = \frac{1}{1+e^{-x}}
# \end{align*}
#
# La funcion anterior tiene el siguiente comportamiento cuando $x\to\infty$:
#
# \\
# \begin{align*}
#     \lim_{x\to\infty} h(x) &= 1
# \end{align*}
# La explicación es la siguiente:
# *   cuando $x\to\infty$, $e^{-x}$ se hace 0, por lo tanto $h(x) = \frac{1}{1+0} = 1$.
#
# \\
# Luego, la funcion anterior tiene el siguiente comportamiento cuando $x\to -\infty$:
# \begin{align*}
#     \lim_{x\to-\infty} h(x)&= 0
# \end{align*}
# La explicación es la siguiente:
# *   cuando $x\to -\infty$, $e^{-x}$ se hace $\infty$, de aqui el denominador de $h(x)$ se hace $\infty$, por lo tanto $h(x) = \frac{1}{\infty} = 0$.
#
# *Posdata: Matemáticamente lo podemos expresar en otro notebook, en este dejamos de lado mucho las expresiones matemáticas para entenderlo en comportamiento de $h(x)$.

# %%
import torch
import torch.nn as nn

# %% [markdown]
# <div style="display: flex; flex-direction: row;justify-content: space-between;">
#   <img src="https://github.com/Noodle96/Topicos_Inteligencia_Artificial/blob/main/assets/img/out01.png?raw=true" width="40%">
#
#   <img src="https://github.com/Noodle96/Topicos_Inteligencia_Artificial/blob/main/assets/img/out02.png?raw=true" width="40%">
# </div>

# %%
input_tensor = torch.tensor([[6.0]])
sigmoid = nn.Sigmoid()
output = sigmoid(input_tensor)
output
# Out:
# tensor([[0.9975]])

# %%
input_np = np.array([[6.0]])
sigmoidea_np = sigmoid(input_np)
sigmoidea_np
# Out:
# array([[0.99752738]])
